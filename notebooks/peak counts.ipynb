# %%
import sys
sys.path.append("/global/home/users/avirukt/name/")
from power_spectrum import *

model = LFI(["field"], 
            [r"$M_\nu$",r"$\Omega_m$",r"$A_s\times10^9$"], 
            model_dir="/global/scratch/avirukt/models/peak_counts-c3d5f50"
           )
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/global/scratch/avirukt/models/peak_counts-c3d5f50', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x2b77f938b4a8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
x_test = load("../data_peak_counts/x_test.npy")
p_test = load("../data_peak_counts/p_test.npy")

# %%
lower = np.array([0, 0, 0.4])
upper = np.array([.7, 0.6, 4])
bounds = list(zip(lower,upper))

# %%
p = model.plot_posteriors(x_test,p_test,bounds=bounds)

# %%
[next(p) for i in range(20)]
6
# Out:
# 6

# %%
model.plot_ranks(x_test,p_test)
# Out:
# /global/home/users/avirukt/.conda/envs/tensorflow/lib/python3.6/site-packages/numpy/lib/type_check.py:546: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   'a.item() instead', DeprecationWarning, stacklevel=1)
# /global/home/users/avirukt/.conda/envs/tensorflow/lib/python3.6/site-packages/numpy/lib/type_check.py:546: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   'a.item() instead', DeprecationWarning, stacklevel=1)
# /global/home/users/avirukt/.conda/envs/tensorflow/lib/python3.6/site-packages/numpy/lib/type_check.py:546: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   'a.item() instead', DeprecationWarning, stacklevel=1)
# /global/home/users/avirukt/.conda/envs/tensorflow/lib/python3.6/site-packages/numpy/lib/type_check.py:546: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
# ...

# %%
model2 = LFI(["field"], 
            [r"$M_\nu$",r"$\Omega_m$",r"$A_s\times10^9$"], 
            model_dir="/global/scratch/avirukt/models/peak_counts-5798108"
           )

# %%
p = model2.plot_posteriors(x_test,p_test,bounds=bounds)

# %%
[next(p) for i in range(20)]
6
# Out:
# /global/home/users/avirukt/.conda/envs/tensorflow/lib/python3.6/site-packages/numpy/lib/type_check.py:546: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   'a.item() instead', DeprecationWarning, stacklevel=1)
# /global/home/users/avirukt/.conda/envs/tensorflow/lib/python3.6/site-packages/numpy/lib/type_check.py:546: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   'a.item() instead', DeprecationWarning, stacklevel=1)
# /global/home/users/avirukt/.conda/envs/tensorflow/lib/python3.6/site-packages/numpy/lib/type_check.py:546: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   'a.item() instead', DeprecationWarning, stacklevel=1)
# /global/home/users/avirukt/.conda/envs/tensorflow/lib/python3.6/site-packages/numpy/lib/type_check.py:546: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
# ...

# %%
model2.plot_ranks(x_test,p_test)
# Out:
# /global/home/users/avirukt/.conda/envs/tensorflow/lib/python3.6/site-packages/numpy/lib/type_check.py:546: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   'a.item() instead', DeprecationWarning, stacklevel=1)
# /global/home/users/avirukt/.conda/envs/tensorflow/lib/python3.6/site-packages/numpy/lib/type_check.py:546: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   'a.item() instead', DeprecationWarning, stacklevel=1)
# /global/home/users/avirukt/.conda/envs/tensorflow/lib/python3.6/site-packages/numpy/lib/type_check.py:546: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   'a.item() instead', DeprecationWarning, stacklevel=1)
# /global/home/users/avirukt/.conda/envs/tensorflow/lib/python3.6/site-packages/numpy/lib/type_check.py:546: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
# ...

# %%
model
